# %% [markdown]
# ## Basic Setup

# %%
import pandas as pd


csv_file_path = 'clean_merged_playerdata_with_weather-2.csv'

df = pd.read_csv(csv_file_path)

# %% [markdown]
# ## Cleaning

# %%
df = df.drop(["bet_type", "open_time", "close_time", "book"], axis=1)
